# %% [markdown]
# <a href="https://colab.research.google.com/github/2stndard/polars/blob/main/2%EC%9E%A5_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print(data)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
print(data['c'])
# Out:
# 30

# %%
df = pd.DataFrame({'Name': ['Kim', 'Sophie', 'Sara', 'Cyrus', 'Lee', 'James', 'Daniel'],
    	'Age': [28, 24, 35, 32, 48, 27, 34],
    	'City': ['Seoul', 'Paris', 'Berlin', 'London', 'Busan', 'NewYork', 'Seattle'],
        'Sex' : ['Man', 'Woman', 'Woman', 'Man', 'Man', 'Man', 'Man'],
        'Continent' : ['Asia', 'Europe', 'Europe', 'Europe', 'Asia',
                       'America', 'America']})
print(df)
# Out:
#      Name  Age     City    Sex Continent
# 0     Kim   28    Seoul    Man      Asia
# 1  Sophie   24    Paris  Woman    Europe
# 2    Sara   35   Berlin  Woman    Europe
# 3   Cyrus   32   London    Man    Europe
# 4     Lee   48    Busan    Man      Asia
# 5   James   27  NewYork    Man   America
# 6  Daniel   34  Seattle    Man   America

# %%
df.head(2)
# Out:
#      Name  Age   City    Sex Continent
# 0     Kim   28  Seoul    Man      Asia
# 1  Sophie   24  Paris  Woman    Europe

# %%
df['City']
# Out:
# 0      Seoul
# 1      Paris
# 2     Berlin
# 3     London
# 4      Busan
# 5    NewYork
# 6    Seattle
# Name: City, dtype: object

# %%
df.loc[3]  ## 행 인덱스 번호를 사용한 행 추출
# Out:
# Name          Cyrus
# Age              32
# City         London
# Sex             Man
# Continent    Europe
# Name: 3, dtype: object

# %%
df.loc[2, 'City'] ## 행 인덱스 번호와 열 이름을 사용한 데이터 추출
# Out:
# 'Berlin'

# %%
df.loc[0:2, 'Age':'City'] ## 행 인덱스 범위와 열 이름 범위를 사용한 데이터프레임 슬라이싱
# Out:
#    Age    City
# 0   28   Seoul
# 1   24   Paris
# 2   35  Berlin

# %%
df.iloc[0] ## 정수형 인덱스로 특정 행 추출하기
# Out:
# Name           Kim
# Age             28
# City         Seoul
# Sex            Man
# Continent     Asia
# Name: 0, dtype: object

# %%
df.iloc[0, 1] ## 첫 번째 행과 두 번째 열의 데이터 추출
# Out:
# 28

# %%
df.iloc[0:2, 1:3] ## 첫 번째부터 두 번째 행, 두 번째 열부터 세 번째 열까지의 데이터프레임 슬라이싱
# Out:
#    Age   City
# 0   28  Seoul
# 1   24  Paris

# %%
df.loc[7] = ['Kofi', 55, 'Cape Town', 'Man', None]
df
# Out:
#      Name  Age       City    Sex Continent
# 0     Kim   28      Seoul    Man      Asia
# 1  Sophie   24      Paris  Woman    Europe
# 2    Sara   35     Berlin  Woman    Europe
# 3   Cyrus   32     London    Man    Europe
# 4     Lee   48      Busan    Man      Asia
# 5   James   27    NewYork    Man   America
# 6  Daniel   34    Seattle    Man   America
# 7    Kofi   55  Cape Town    Man      None

# %%
df[df['Age'] > 30] ## Age가 30보다 큰 데이터 필터링
# Out:
#      Name  Age       City    Sex Continent
# 2    Sara   35     Berlin  Woman    Europe
# 3   Cyrus   32     London    Man    Europe
# 4     Lee   48      Busan    Man      Asia
# 6  Daniel   34    Seattle    Man   America
# 7    Kofi   55  Cape Town    Man      None

# %%
df[(df['Age'] < 30) & (df['City'] == 'Seoul')] ## 두가지 조건을 사용한 데이터 필터링
# Out:
#   Name  Age   City  Sex Continent
# 0  Kim   28  Seoul  Man      Asia

# %%
df.dropna()
# Out:
#      Name  Age     City    Sex Continent
# 0     Kim   28    Seoul    Man      Asia
# 1  Sophie   24    Paris  Woman    Europe
# 2    Sara   35   Berlin  Woman    Europe
# 3   Cyrus   32   London    Man    Europe
# 4     Lee   48    Busan    Man      Asia
# 5   James   27  NewYork    Man   America
# 6  Daniel   34  Seattle    Man   America

# %%
df.sort_values(by = 'Age', ascending=False)
# Out:
#      Name  Age       City    Sex Continent
# 7    Kofi   55  Cape Town    Man      None
# 4     Lee   48      Busan    Man      Asia
# 2    Sara   35     Berlin  Woman    Europe
# 6  Daniel   34    Seattle    Man   America
# 3   Cyrus   32     London    Man    Europe
# 0     Kim   28      Seoul    Man      Asia
# 5   James   27    NewYork    Man   America
# 1  Sophie   24      Paris  Woman    Europe

# %%
df.groupby('Continent')['Name'].count()
# Out:
# Continent
# America    2
# Asia       2
# Europe     3
# Name: Name, dtype: int64

# %%
df.groupby('Continent').agg({'Age': 'mean', 'Name': 'count'})
# Out:
#                  Age  Name
# Continent
# America    30.500000     2
# Asia       38.000000     2
# Europe     30.333333     3
